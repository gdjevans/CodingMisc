# %%
#Section 7.1

# %%
#these are all my imports
import pandas as pb
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime

# %%
#time logger block for version control
now = datetime.now()
time_log = now.strftime("%m-%d-%Y, %H:%M:%S")
print("Above Executed @ or B4:", time_log)
# Out:
# Above Executed @ or B4: 05-27-2022, 00:01:23

# %%
df_titanic = sns.load_dataset("titanic")
df_iris = sns.load_dataset("iris")

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#time logger block for version control
now = datetime.now()
time_log = now.strftime("%m-%d-%Y, %H:%M:%S")
print("Above Executed @ or B4:", time_log)
# Out:
# Above Executed @ or B4: 05-27-2022, 00:07:43

# %%
#Section 7.2

# %%
df_titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#bar graph skeleton code
sns.catplot(x = "sex", data = df_titanic, kind = "count" )
plt.show()

# %%
#bar graph skeleton code
sns.catplot(y = "sex", data = df_titanic, kind = "count" )
plt.show()

# %%
#bar graph skeleton code
sns.catplot(x = "sex", data = df_titanic, kind = "count", hue="class" )
plt.show()

# %%
#bar graph skeleton code
sns.catplot(x = "species", data = df_iris, kind = "count" )
plt.show()

# %%
# Section 7.3

# %%
#time logger block for version control
now = datetime.now()
time_log = now.strftime("%m-%d-%Y, %H:%M:%S")
print("Above Executed @ or B4:", time_log)
# Out:
# Above Executed @ or B4: 05-27-2022, 00:14:34

# %%
sns.kdeplot(df_iris["sepal_length"], color = "red", label="Sepal Length")
sns.kdeplot(df_iris["sepal_width"], color = "blue", label="Sepal Width")
plt.legend()
plt.show()

# %%
sns.histplot(df_iris["sepal_length"], color = "red", label="Sepal Length")
sns.histplot(df_iris["sepal_width"], color = "blue", label="Sepal Width")
plt.legend()
plt.show()

# %%
sns.regplot(df_iris["petal_length"], y=df_iris["sepal_length"])
plt.show();
# Out:
# c:\Users\GDJEvans\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
